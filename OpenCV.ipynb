# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('img1.jpg', 0)
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('img1.jpg', 0)
cv2.imshow('image', img)
key = cv2.waitKey(0)
if key == ord('s'):
    cv2.imwrite('img2.png', img)
cv2.destroyAllWindows()

# %%
img = cv2.imread('img1.jpg', -1)
plt.imshow(img)
plt.show()

# %%
print(img.shape)
print(img.size)
# Out:
# (576, 576, 3)
# 995328

# %%
r,g,b = cv2.split(img)
print(r.shape)
print(g.shape)
print(b.shape)
# Out:
# (576, 576)
# (576, 576)
# (576, 576)

# %%
img1 = cv2.imread('img1.jpg')
img2 = cv2.imread('img2.png')

dest1 = cv2.bitwise_and(img1,img2,mask=None)
dest2 = cv2.bitwise_or(img2,img1,mask=None)
dest3 = cv2.bitwise_xor(img1,img2,mask=None)

cv2.imshow('A', img1)
cv2.imshow('B', img2)
cv2.imshow('AND', dest1)
cv2.imshow('OR', dest2)
cv2.imshow('XOR', dest3)
cv2.imshow('NOT A', cv2.bitwise_not(img1))
cv2.imshow('NOT B', cv2.bitwise_not(img2))

if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %%
img = cv2.imread('img1.jpg',1)
cv2.line(img,(0,400),(500,400),(255,0,0),5)
cv2.circle(img,(250,150), 90, (0,255,0), 5)
cv2.rectangle(img,(400,100),(100,500),(0,0,255),5)
plt.imshow(img)
plt.show()

# %%
img1 = cv2.imread('img1.jpg')
txt = 'IBRAHIM'
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img1, txt, (10,100), font, 3, (255,255,255), cv2.LINE_AA)
plt.imshow(img1)
plt.show()
